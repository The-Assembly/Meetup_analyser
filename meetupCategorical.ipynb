# %%
import pandas as pd
import meetup.api
import json
import requests
import time
import codecs
import sys
import io
import matplotlib.pyplot as plt

df = pd.read_json("dfw4.json")
names=df['name']

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, df['yes_rsvp_count'])
plt.subplot(132)
plt.scatter(names, df['yes_rsvp_count'])
plt.subplot(133)
plt.plot(names, df['rsvp_limit'])
plt.suptitle('Categorical Plotting')
plt.show()
